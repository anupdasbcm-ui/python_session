# %% [markdown]
# **Dictionary Method**

# %%
dir({})
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %% [markdown]
# $items-keys-values$

# %%
d1={'Ram':25,'Raheem':30,'Robert':35}
d1
# Out:
# {'Ram': 25, 'Raheem': 30, 'Robert': 35}

# %%
#items
d1.items()
# Out:
# dict_items([('Ram', 25), ('Raheem', 30), ('Robert', 35)])

# %%
# keys
keys=d1.keys()
keys
# Out:
# dict_keys(['Ram', 'Raheem', 'Robert'])

# %%
# values
values=d1.values()
values
# Out:
# dict_values([25, 30, 35])

# %%
type(values)
# Out:
# dict_values

# %%
type(d1.items())
# Out:
# dict_items

# %%
type(d1.keys())
# Out:
# dict_keys

# %%
type(d1.values())
# Out:
# dict_values

# %%
l1=[25,30,35]
l1.append(400)
l1
# Out:
# [25, 30, 35, 400]

# %%
values       # I want to convert into a list
list(values)  # then you can apply the list method.
# Out:
# [25, 30, 35]

# %%
keys_list=list(keys)
keys_list
# Out:
# ['Ram', 'Raheem', 'Robert']

# %%
# I will give the dictionary
# can you extract keys ans values in a list



# I will give two list keys and values
# can you create a dictionary

# %%
d1={'ram':25,'raheem':30,'robert':35}

keys=list(d1.keys())
values=list(d1.values())

# %%
keys,values
# Out:
# (['ram', 'raheem', 'robert'], [25, 30, 35])

# %%
# now make a dictionary.
dict1={}
for i in range(len(keys)):
    dict1[keys[i]]=values[i]

dict1
# Out:
# {'ram': 25, 'raheem': 30, 'robert': 35}

# %%
{keys:values for keys,values in zip(keys,values)}
# Out:
# {'ram': 25, 'raheem': 30, 'robert': 35}

# %%
{i:j for i,j in zip(keys,values)}
# Out:
# {'ram': 25, 'raheem': 30, 'robert': 35}

# %%
s1='virat.kohli@blr.com,rohit.sharma@mumbai.com,kl.rahul@lucknow.com'

# {'first_name':['virat','Rohit','Kl'],
#   'second_name':['kohli','sharma','rahul'],
#   'company':['blr','mumbai','lucknow']}

# %%
s1.split(',')
# Out:
# ['virat.kohli@blr.com', 'rohit.sharma@mumbai.com', 'kl.rahul@lucknow.com']

# %%
first_name=[]
second_name=[]
company=[]
d2={}
for i in s1.split(','):
    first_name.append(i[0:i.find('.')])
    second_name.append(i[i.find('.')+1:i.find('@')])
    company.append(i[i.find('@')+1:i.find('.',i.find('.')+1)])

d2['first_name']=first_name
d2['second_name']=second_name
d2['company']=company
d2
# Out:
# {'first_name': ['virat', 'rohit', 'kl'],
#  'second_name': ['kohli', 'sharma', 'rahul'],
#  'company': ['blr', 'mumbai', 'lucknow']}

# %% [markdown]
# $word frequency$

# %%
'can can you canner can you able to can canner'
# wap to get the words frequency (which word is how many time repeated.)

#{'can':4,'you':2,'canner':2,'able':1,'to':1}

# %%
str1='can can you canner can you able to can canner'
str1.split(' ')
# Out:
# ['can', 'can', 'you', 'canner', 'can', 'you', 'able', 'to', 'can', 'canner']

# %%
l1=str1.split(' ')
d3={}

for i in l1:
    d3[i]=l1.count(i)

d3
# Out:
# {'can': 4, 'you': 2, 'canner': 2, 'able': 1, 'to': 1}

# %%
keys=list(d3.keys())

# %%
values=list(d3.values())

# %%
keys,values
# Out:
# (['can', 'you', 'canner', 'able', 'to'], [4, 2, 2, 1, 1])

# %%
i=max(values)

# %%
values.index(i)
# Out:
# 0

# %%
keys[values.index(i)]
# Out:
# 'can'

# %%
d1={'a':20,'b':30,'c':40}
d2={'a':50,'b':100,'c':200}
for i in d1:
    d1[i]+=d2[i]
d1
#output={'a':70,'b':130,'c':240}
# Out:
# {'a': 70, 'b': 130, 'c': 240}

# %%
d1={'a':20,'b':30,'c':40}
d2={'a':50,'b':100,'c':200}

d3={}
if len(d1)==len(d2):
    for i in d1:
        d3[i]=d1[i]+d2[i]     #d3['a']=d1['a']+d2['a']

d3
# Out:
# {'a': 70, 'b': 130, 'c': 240}

# %%
# strings/list/dictionary
