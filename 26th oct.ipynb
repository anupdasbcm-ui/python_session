# %%
# what is variable

Number =100
Number
# Out:
# 100

# %%
sum123=500
sum123
# Out:
# 500

# %%
add_one=600
add_one
# Out:
# 600

# %%
_=600
_
# Out:
# 600

# %%
import random
random.randint(1,100)
# Out:
# 81

# %%
$integer$
# Out:
#   Cell In[1], line 1
#     $integer$
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# $integer$

# %%
number=100

# %%
# type of the variable : type
type(number)
# Out:
# int

# %%
string1='python'
string1
# Out:
# 'python'

# %%
value=False
value
# Out:
# False

# %%
type(value)
# Out:
# bool

# %%
name1=True
name2=true
name3="True"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 name1=True
# ----> 2 name2=true
#       3 name3="True"
#
# NameError: name 'true' is not defined

# %%
a=100
b=200
a=b
b=a
a=500
b=a
b=900
a
# Out:
# 500

# %%
complex()
# Out:
# 0j

# %%
import random

# %%
dir (random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  '_warn',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
help (random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
random.randint(1,100)
# Out:
# 72

# %%
number1=100

# %%
Float_number=float(number1)

# %%
Float_number
# Out:
# 100.0

# %%
type(Float_number)
# Out:
# float

# %%
string_number=str(number1)

# %%
string_number
# Out:
# '100'

# %%
val1=True
int(val1)
# Out:
# 1

# %%
float(val1)
# Out:
# 1.0

# %%
str(val1)
# Out:
# 'True'

# %%
complex(val1)
# Out:
# (1+0j)

# %%
val2=100+200j
int(val2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 val2=100+200j
# ----> 2 int(val2)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
str(val2)
# Out:
# '(100+200j)'

# %%
bool(val2)
# Out:
# True

# %%
float(val2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 float(val2)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
val3=100+0j
int(val3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 val3=100+0j
# ----> 2 int(val3)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
str(val3)
# Out:
# '(100+0j)'

# %%
float(val3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 float(val3)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
basic_salary=100
DA_amount=20
HRA_amount=20
basic_salary+DA_amount+HRA_amount
# Out:
# 140

# %%
basic_salary=eval(input("enter a basic salary"))
DA=eval(input("enter DA amount"))
HRA=eval(input("enter HRA amount"))
Total_pay=basic_salary+DA+HRA
print("total salary:",Total_pay)
# Out:
# enter a basic salary 50000
# enter DA amount 20000
# enter HRA amount 10000
# total salary: 80000

# %%
basic_salary
# Out:
# 50000

# %%
salary=eval(input("salary"))
Tax_percentage=eval(input("Tax_percentage"))
Tax=salary*(Tax_percentage/100)
print("Tax:",Tax)
# Out:
# salary 100000
# Tax_percentage 10
# Tax: 10000.0

# %%
import random

# %%
random.randint(1,100)
# Out:
# 59

# %%
randomm=(random.randint(1,100))
square=randomm*randomm
print("square of {} is {}".format(randomm,square))
# Out:
# square of 6 is 36

# %%
distance=eval(input("distance"))
rate_per_distance=eval(input("rate_per_distance"))
total_charge=distance*rate_per_distance
print("total_charge:",total_charge)
# Out:
# distance 100
# rate_per_distance 10
# total_charge: 1000

# %%
# ask the user enter total bill in dollars : 100
# manger: the dollars are not accepted
# user : what will accepted
# manager : only indian rupees
# ask the user enter one dollar is equal to how many rupees: 80
# total bill = 100*80
# manager: Thank you!

# %%
bill=eval(input("enter total bill in dollars"))
conversion_rate=eval(input("one dollar equal to:"))
total_amount=bill*conversion_rate
print(total_amount)
# Out:
# enter total bill in dollars 100
# one dollar equal to: 80
# 8000

# %%
bill=eval(input("enter total bill in dollars: "))
print("Manager: the dollars are not accepted")
print("User: which currency will be accepted") 
print("manager: Only Indian rupee")
conversion_rate=eval(input("User: May i know 1 dollars equals to how much in rupees?"))
print("For your bill of {} dollars, you need to pay {} rs.".format(bill,bill*conversion_rate))
# Out:
# enter total bill in dollars:  100
# Manager: the dollars are not accepted
# User: which currency will be accepted
# manager: Only Indian rupee
# User: May i know 1 dollars equals to how much in rupees? 80
# For your bill of 100 dollars, you need to pay 8000 rs.

# %%
import time
bill=eval(input("enter total bill in dollars: "))
time.sleep(2)
print("Manager: the dollars are not accepted")
time.sleep(2)
print("User: which currency will be accepted") 
time.sleep(2)
print("manager: Only Indian rupee")
time.sleep(2)
conversion_rate=eval(input("User: May i know 1 dollars equals to how much in rupees?"))
time.sleep(2)
print("For your bill of {} dollars, you need to pay {} rs.".format(bill,bill*conversion_rate))
# Out:
# enter total bill in dollars:  100
# Manager: the dollars are not accepted
# User: which currency will be accepted
# manager: Only Indian rupee
# User: May i know 1 dollars equals to how much in rupees? 80
# For your bill of 100 dollars, you need to pay 8000 rs.

# %%
Bill=eval(input("Manager:Enter the total bill in dollars:"))
input("Manager Response:")
input("User Response:")
input("Manager Response:")
CR=eval(input("Dollar conversion:"))
Total=Bill*CR
print('Total Amount',Total)
# Out:
# Manager:Enter the total bill in dollars: 100
# Manager Response: NA
# User Response: What
# Manager Response: Inr
# Dollar conversion: 80
# Total Amount 8000

# %%
salary=eval(input('salary'))
tax_percentage=eval(input('tax'))
tax_amount=(salary*tax_percentage)/100
print("total tax is",tax_amount)
# Out:
# salary 100000
# tax 10
# total tax is 10000.0

# %%
# WAP ask the user get a random value between 1 and 100
# perform the square of the number

# %%
import random
random.randint(1,100)
randomm=random.randint(1,100)
square=randomm*randomm
print('The Square of {} is {}'.format(randomm,square))
# Out:
# The Square of 92 is 8464
