# %%
num1=eval(input('enter a number1:'))
num2=eval(input('enter a number2:'))
add=num1+num2
print(add)
# Out:
# enter a number1: 100
# enter a number2: 200
# 300

# %%
# error 1 : name error: num3 is not defined
num1=eval(input('enter a number1:'))
num2=eval(input('enter a number2:'))
add=num1+num3
print(add)
# Out:
# enter a number1: 100
# enter a number2: 200
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       2 num1=eval(input('enter a number1:'))
#       3 num2=eval(input('enter a number2:'))
# ----> 4 add=num1+num3
#       5 print(add)
#
# NameError: name 'num3' is not defined

# %%
# error 2: syntax error
num1=eval(input('enter a number1:')
num2=eval(input('enter a number2:'))
add=num1+num2
print(add)
# Out:
#   Cell In[7], line 2
#     num1=eval(input('enter a number1:')
#              ^
# SyntaxError: '(' was never closed

# %%
# error 3:
num1=eval(input('enter a number1:'))
num2=eval(input('enter a number2:'))
add=num1/num2
print(add)
# Out:
# enter a number1: 100
# enter a number2: 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[8], line 4
#       2 num1=eval(input('enter a number1:'))
#       3 num2=eval(input('enter a number2:'))
# ----> 4 add=num1/num2
#       5 print(add)
#
# ZeroDivisionError: division by zero

# %%
# error 4:
num1=input('enter a number1:')  #string
num2=eval(input('enter a number2:')) #int
add=num1/num2   # string/int
print(add)
# Out:
# enter a number1: 10
# enter a number2: 20
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       2 num1=input('enter a number1:')  #string
#       3 num2=eval(input('enter a number2:')) #int
# ----> 4 add=num1+num2   # string/int
#       5 print(add)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# error 5:
num1=eval(input('enter a number1:'))
num2=eval(input('enter a number2:'))
add=num1+num2
print add
# Out:
#   Cell In[11], line 5
#     print add
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
num1=eval(input('enter a number1:'))
num2=eval(input('enter a number2:'))
add=num1+num2
Print(add)
# Out:
# enter a number1: 100
# enter a number2: 200
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       2 num2=eval(input('enter a number2:'))
#       3 add=num1+num2
# ----> 4 Print(add)
#
# NameError: name 'Print' is not defined

# %% [markdown]
# suppose you have written 500 lines of code at 200 line you got an error.This error might not impact your code.so you want to execute after 200 line also
#
# ### Exceptional handling

# %% [markdown]
# $try$-$except$
# - there are two blocks
#
# - one try block
#
# - another is exception block
#
# - your code will be there in try block
#
# - error capture will happens in except block
#
# - indentation : space
#
# - red : space/indentation not maintained properly.
#
# - indentation has min 4 characters
#
# - if : is there,then there will be indentation.

# %%
# Method-1
try:
    num1=10
    num2=20
    num3=30
    add=num1/num2    
    print(add)

except:
    print('error is there, check code')
# Out:
# 0.5

# %%
num1=10
num2=20
num3=30
add=num1+num2+num3
print(add)
# Out:
# 60

# %%
# Method-2
try:
    num1=10
    num2=0
    num3=30
    add=num1/num2    #10/0 =======> zero
    print(add)

except:
    print('error is there, check code')
# Out:
# error is there, check code

# %%
# wap ask the user enter 3 numbers and find the average
num1=eval(input("enter number 1:"))
num2=eval(input("enter number 2:"))
num3=eval(input("enter number 3:"))
average=(num1+num2+num3)/3
print('The average of {} , {} and {} is {}'.format(num1,num2,num3,average))
# Out:
# enter number 1: 20
# enter number 2: 30
# enter number 3: 40
# The average of 20 , 30 and 40 is 30.0

# %%
try:
    num1=eval(input("enter number 1:"))
    num2=eval(input("enter number 2:"))
    num3=eval(input("enter number 3:"))
    average=(num1+num2+num333)/3
    print('The average of {} , {} and {} is {}'.format(num1,num2,num3,average))
    

except:
    print('error is there, check code')
# Out:
# enter number 1: 10
# enter number 2: 20
# enter number 3: 30
# error is there, check code

# %%
try:
    num1=eval(input("enter number 1:"))
    num2=eval(input("enter number 2:"))
    num3=eval(input("enter number 3:"))
    average=(num1+num2+num333)/3
    print('The average of {} , {} and {} is {}'.format(num1,num2,num3,average))
    

except Exception as e:
    print(e)

# error-1: name error
# Out:
# enter number 1: 10
# enter number 2: 20
# enter number 3: 30
# name 'num333' is not defined

# %%
# wap ask the user enter a number and find the square of the number

# %%
try:
    num1=eval(input('enter a num:'))
    square=num1*num12
    print('The square of {} is {}'.format(num1,square))

except Exception as e:
    print(e)
# Out:
# enter a num: 10
# name 'num12' is not defined

# %%
num1=eval(input('enter number 1'))
square=num1*num1
print('the square of {} is {}'.format(num1,square))
# Out:
# enter number 1 10
# the square of 10 is 100

# %%
try:
    num1=eval(input('enter number 1:'))
    square=num1*num12
    print('the square of {} is {}'.format(num1,square))

except Exception as e:
    print(e)
# Out:
# enter number 1: 10
# name 'num12' is not defined

# %%
sys
traceback
looger

# %%
import sys
sys.exc_info()
# Out:
# (None, None, None)

# %%
try:
    num1=eval(input('enter number 1:'))
    square=num1*num12
    print('the square of {} is {}'.format(num1,square))

except Exception as e:
    print(e)
    print('hello') #this is the best use of try and except, even you get the error,the code will going to run.
# Out:
# enter number 1: 10
# name 'num12' is not defined
# hello

# %%
try:
    num1=eval(input('enter number 1:'))
    square=num1*num12
    print('the square of {} is {}'.format(num1,square))

except Exception as e:
    print('hai')
    print(e)
    print('hello')
# Out:
# enter number 1: 10
# hai
# name 'num12' is not defined
# hello

# %%
try:
    num1=eval(input('enter number 1'))
    square=num1*num12
    print('the square of {} is {}'.format(num1,square))

except Exception as e:
    print(e)
    print('hello')

print('python')
print(1)
print(2)
# Out:
# enter number 1 10
# name 'num12' is not defined
# hello
# python
# 1
# 2

# %%
only try block content is printed

# %%
- if your code is without error, try block will execute 

- if your code has error, it will redirect to except block

- whatever you written inside except block that will run

- try and except is together

- once try and exceptions code are complete, it try to look any other lines of codes are there.

# %%
print("======================")
print(3+5)
print('*************************')
try:
    num=eval(input("enter a number"))
    print("the square of {} is {}" .format(num,num222*num)) # error

except Exception as e:
    print('hai')
    print(e)
    print('hello')

print('python')
print(1)
print(2)
# Out:
# ======================
# 8
# *************************
# enter a number 10
# hai
# name 'num222' is not defined
# hello
# python
# 1
# 2

# %%
print("======================")
print(3+5)
print('*************************')
try:
    num=eval(input("enter a number"))
    print("the square of {} is {}" .format(num,num222*num)) # error

print('jai')

except Exception as e:
    print('hai')
    print(e)
    print('hello')

print('python')
print(1)
print(2)
# Out:
#   Cell In[2], line 8
#     print('jai')
#     ^
# SyntaxError: expected 'except' or 'finally' block

# %%
try:
    num1=eval(input("enter a no.:"))
    square=num1*num2

except Exception as e:
    print(e)
# Out:
# enter a no.: 10
# name 'num2' is not defined
