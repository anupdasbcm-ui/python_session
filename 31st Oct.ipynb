# %% [markdown]
# **Functions**

# %% [markdown]
# - reuse any part of code

# %%
n1=10
n2=20
add=n1+n2
print("the addition of {} and {} is {}".format(n1,n1,add))
# Out:
# the addition of 10 and 10 is 30

# %%
# the function keyword statr with the def<function_name>():

# %%
def <function_name>():
    # write your code here

# %%
def addition():
    n1=10
    n2=20
    add=n1+n2
    print("the addition of {} and {} is {}".format(n1,n1,add))

# %%
# the output will not display untill unless you call the function

# %%
addition()
# Out:
# the addition of 10 and 10 is 30

# %%
def addition():
    n1=eval(input('enter number'))
    print('hello')
    print('I am writing function')

# %%
addition()
# Out:
# enter number 20
# hello
# I am writing function

# %%
# python will take latest value one

# %%
# In this particular cell: 500 lines

# %%
# line1

# %%
# line2

# %%
n1=100

# %%
n2=200

# %%
print(n1+n2)
# Out:
# 30

# %%
def hello_world():
    print('hello good morning')

hello_world()
# Out:
# hello good morning

# %%
# Take three numbers, find the average
# WAP ask the user enter 3 numbers
# n1=eval(input())
# n2=eval(input())
# n3=eval(input())
# Avg=(n1+n2+n3)/3
# First write normal code
# Then implement the function

# %%
n1=eval(input("Enter the first number:"))
n2=eval(input("Enter the second number:"))
n3=eval(input("Enter the third number:"))
Avg=(n1+n2+n3)/3
print(Avg)
# Out:
# Enter the first number: 10
# Enter the second number: 20
# Enter the third number: 30
# 20.0

# %%
def avg():
    n1=eval(input("Enter the first number:"))
    n2=eval(input("Enter the second number:"))
    n3=eval(input("Enter the third number:"))
    Avg=(n1+n2+n3)/3
    print(Avg)

# %%
avg()
# Out:
# Enter the first number: 10
# Enter the second number: 20
# Enter the third number: 30
# 20.0

# %%
def avg():
    n1=eval(input("Enter the first number:"))
    n2=eval(input("Enter the second number:"))
    n3=eval(input("Enter the third number:"))
    Avg=(n1+n2+n3333)/3
    print(Avg)

# %%
avg()
# Out:
# Enter the first number: 10
# Enter the second number: 20
# Enter the third number: 100
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 avg()
#
# Cell In[1], line 5, in avg()
#       3 n2=eval(input("Enter the second number:"))
#       4 n3=eval(input("Enter the third number:"))
# ----> 5 Avg=(n1+n2+n3333)/3
#       6 print(Avg)
#
# NameError: name 'n3333' is not defined

# %%
**Note**:
  we are not sure, whether the function is defined correct or not untill unless we call the function.

# %%
def avg():
    try:
        n1=eval(input("Enter the first number:"))
        n2=eval(input("Enter the second number:"))
        n3=eval(input("Enter the third number:"))
        Avg=(n1+n2+n33)/3
        print(Avg)
    except Exception as e:
        print(e)

# %%
avg()
# Out:
# Enter the first number: 50
# Enter the second number: 100
# Enter the third number: 200
# name 'n33' is not defined

# %%
# WAP ask the user enter bill amount
# ask the user enter tip amount
# calculate total bill

# first write normal code
# Then define the function.

# %%
def Bill():
    n1=eval(input("enter the bill amount"))
    n2=eval(input("enter the tip"))
    Total=n1+n2
    print('total bill:{}'.format(Total))

# %%
Bill():
# Out:
#   Cell In[14], line 1
#     Bill():
#           ^
# SyntaxError: invalid syntax

# %%
 n1=eval(input("enter the bill amount"))
 n2=eval(input("enter the tip"))
 Total=n1+n2
 print('total bill:{}'.format(Total))
# Out:
# enter the bill amount 20
# enter the tip 3
# total bill:23

# %%
#wap ask the user get a random number betwenn 1 to 100
#print it is even or odd number
#implement using function

# %%
import random
num=random.randint(1,100)
if num%2==0:
    print("{} is an even number".format(num))
else:
    print("{} is an odd number".format(num))
# Out:
# 87 is an odd number

# %%
import random
def even_odd():
    num=random.randint(1,100)
    if num%2==0:
        print("{} is an even number".format(num))
    else:
        print("{} is an odd number".format(num))

even_odd()
# Out:
# 85 is an odd number

# %%
import random
def even_odd():
    print("we are implementing even odd function")
    print("take one number")
    num=random.randint(1,100)
    if num%2==0:
        print("the remainder is zero")
        print("{} is an even number".format(num))
    else:
        print("the remainder is not equal to zero")
        print("{} is an odd number".format(num))

even_odd()
# Out:
# we are implementing even odd function
# take one number
# the remainder is not equal to zero
# 65 is an odd number

# %%
import random
print("hello")
print("python")
def even_odd():
    try:
        print("we are implementing even odd function")
        print("take one number")
        num=random.randint(1,100)
        if num%2==0:
            print("the remainder is zero")
            print("{} is an even number".format(num))
        else:
            print("the remainder is not equal to zero")
            print("{} is an odd number".format(num))
    except Exception as e:
            print(e)

print("calling function")
even_odd()
print("done")
# Out:
# hello
# python
# calling function
# we are implementing even odd function
# take one number
# the remainder is not equal to zero
# 43 is an odd number
# done

# %%
def addition():
    n1=20
    n2=30
    print("addition:",n1+n2)

print("mul function starts")
def mul():
    n1=20
    n2=30
    print('mul:',n1*n2)
    print('mul is done')

print("subtraction function starts")
def sub():
    n1=20
    n2=30
    print('sub:',n1-n2)
    print('subtraction is done')

print("anything remains")
print("no")
print("then call the function")

sub()
mul()
addition()
# Out:
# mul function starts
# subtraction function starts
# anything remains
# no
# then call the function
# sub: -10
# subtraction is done
# mul: 600
# mul is done
# addition: 50

# %% [markdown]
# - if you are not mentioning any values inside the function bracket
#
# - without arguments or without parameters
#
# - arguments or parameters

# %% [markdown]
# ***With Arguments***

# %%
def addition():
    n1=10
    n2=20
    add=n1+n2
    print("the addition of {} and {} is {}".format(n1,n2,add))

addition()

#1) inside the function how many variables are there?
#    3 variables are there
#2) how many user provided variables?
#    2 variables

# %%
def addition(n1,n2): # arguments
    add=n1+n2
    print("the addition of {} and {} is {}".format(n1,n2,add))

addition(20,30) #n1=20   n2=30
# Out:
# the addition of 20 and 30 is 50

# %%
def addition(n1,n2): # arguments
    add=n1+n2
    print("the addition of {} and {} is {}".format(n1,n2,add))

addition(20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2     add=n1+n2
#       3     print("the addition of {} and {} is {}".format(n1,n2,add))
# ----> 5 addition(20)
#
# TypeError: addition() missing 1 required positional argument: 'n2'

# %%
def avg():
    try:
        n1=eval(input("Enter the first number:"))
        n2=eval(input("Enter the second number:"))
        n3=eval(input("Enter the third number:"))
        Avg=(n1+n2+n33)/3
        print(Avg)
    except Exception as e:
        print(e)

# Implement below code using with arguments.

# %%
def avg(n1,n2,n3):
    try:
        Avg=(n1+n2+n3)/3
        print(Avg)
    except Exception as e:
        print(e)

avg(20,30,40)
# Out:
# 30.0

# %%
num=12345
v1=num%10
v11=num//10
