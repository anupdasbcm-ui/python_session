# %%
# wap print hello 3 times (whenever u see times/iteration======> loop is the concept)

# %%
# first set up the loop
for i in range(3):
    print("hello")
# Out:
# hello
# hello
# hello

# %%
print('hai')
for i in range(3):
    print('hello')

print('how do you do')
# Out:
# hai
# hello
# hello
# hello
# how do you do

# %%
# A
# A
# A
# B
# B
# C
# C
# C

for i in range(3):
    print('A')

for i in range(2):
    print('B')

for i in range(3):
    print('C')
# Out:
# A
# A
# A
# B
# B
# C
# C
# C

# %%
# A
# B
# A
# B
# A
# B
# C
# C
# C

for i in range(3):
    print('A')
    print('B')
for i in range(3):
    print('C')
# Out:
# A
# B
# A
# B
# A
# B
# C
# C
# C

# %%
# Wap ask the user get the square of the no. b/w 10 to 15.
# Output should be like this:
#   square of 10 is 100.


# first get the numbers from 10 to 15
for i in range(10,16):
    print("The square of {} is {}".format(i,i*i))
# Out:
# The square of 10 is 100
# The square of 11 is 121
# The square of 12 is 144
# The square of 13 is 169
# The square of 14 is 196
# The square of 15 is 225

# %%
# the same above question
# take the numbers from keyboard
# num1=eval(inpu())  10
# num2=eval(input()) 16

num1=eval(input("Enter start num:"))
num2=eval(input("Enter end num:"))
for i in range(num1,num2):
    print("The square of {} is {}".format(i,i*i))
# Out:
# Enter start num: 10
# Enter end num: 16
# The square of 10 is 100
# The square of 11 is 121
# The square of 12 is 144
# The square of 13 is 169
# The square of 14 is 196
# The square of 15 is 225

# %%
for i in range(eval(input("Enter start num:")),eval(input("Enter end num:"))):
    print("The square of {} is {}".format(i,i*i))
# Out:
# Enter start num: 10
# Enter end num: 16
# The square of 10 is 100
# The square of 11 is 121
# The square of 12 is 144
# The square of 13 is 169
# The square of 14 is 196
# The square of 15 is 225

# %%
# function without arguments
def square1():
    num1=eval(input("Enter start num:"))
    num2=eval(input("Enter end num:"))
    for i in range(num1,num2):
        print("The square of {} is {}".format(i,i*i))
    

square1()
# Out:
# Enter start num: 10
# Enter end num: 16
# The square of 10 is 100
# The square of 11 is 121
# The square of 12 is 144
# The square of 13 is 169
# The square of 14 is 196
# The square of 15 is 225

# %%
# Function with arguments
def square1(num1,num2):
    for i in range(num1,num2):
        print("The square of {} is {}".format(i,i*i))

square1(10,16)
# Out:
# The square of 10 is 100
# The square of 11 is 121
# The square of 12 is 144
# The square of 13 is 169
# The square of 14 is 196
# The square of 15 is 225

# %%
# Wap ask the user to print square of the five numbers and these five numbers you need to ask user every time.

for i in range(5):
    num=eval(input('enter a num: '))
    print("the square of {} is {}".format(num,num*num))
# Out:
# enter a num:  10
# the square of 10 is 100
# enter a num:  20
# the square of 20 is 400
# enter a num:  30
# the square of 30 is 900
# enter a num:  40
# the square of 40 is 1600
# enter a num:  50
# the square of 50 is 2500

# %%
num=eval(input('enter a num: '))
for i in range(5):
    print("the square of {} is {}".format(num,num*num))
    
for i in range(5):
    num=eval(input('enter a num: '))
    print("the square of {} is {}".format(num,num*num))
# Out:
# enter a num:  5
# the square of 5 is 25
# the square of 5 is 25
# the square of 5 is 25
# the square of 5 is 25
# the square of 5 is 25
# enter a num:  5
# the square of 5 is 25
# enter a num:  6
# the square of 6 is 36
# enter a num:  7
# the square of 7 is 49
# enter a num:  8
# the square of 8 is 64
# enter a num:  9
# the square of 9 is 81

# %%
# WAP ask the user to print five times square of a number
# this time you need to take every time a random number between 1 to 20.
import random

for i in range(5):
    num=random.randint(1,20)
    print("the square of {} is {}".format(num,num*num))
# Out:
# the square of 13 is 169
# the square of 16 is 256
# the square of 7 is 49
# the square of 5 is 25
# the square of 10 is 100

# %%
# Wap ask the user print the given number is even or odd
# you need to take the number between 10 to 30

# iterate the loop between 10 and 30
# every time apply if i%2==0: print even
#                  else : print odd

for num in range(10,31):
    if num%2==0:
        print("The given {} is even".format(num))

    else:
        print("The given {} is odd".format(num))
# Out:
# The given 10 is even
# The given 11 is odd
# The given 12 is even
# The given 13 is odd
# The given 14 is even
# The given 15 is odd
# The given 16 is even
# The given 17 is odd
# The given 18 is even
# The given 19 is odd
# The given 20 is even
# The given 21 is odd
# The given 22 is even
# The given 23 is odd
# The given 24 is even
# The given 25 is odd
# The given 26 is even
# The given 27 is odd
# The given 28 is even
# The given 29 is odd
# The given 30 is even

# %%
# Wap ask the user print the given number is even or odd
# you need to take the number randomly between 10 to 30
# this process you need to do five no.
# iterate the loop between 10 and 30
# every time apply if i%2==0: print even
#                  else : print odd

# %%
import random
for i in range(5):
    num=random.randint(10,30)
    if num%2==0:
        print("The given {} is even".format(num))

    else:
        print("The given {} is odd".format(num))
# Out:
# The given 29 is odd
# The given 25 is odd
# The given 27 is odd
# The given 22 is even
# The given 10 is even

# %%
def even_odd(num):
    if num%2==0:
        print("the given {} is even".format(num))
    else:
        print("the given {} is odd".format(num))

import random
for i in range(5):
    num=random.randint(10,30)
    even_odd(num)
# Out:
# the given 19 is odd
# the given 22 is even
# the given 22 is even
# the given 10 is even
# the given 15 is odd

# %%
import random
def even_odd(num):
    if num%2==0:
        print("the given {} is even".format(num))
    else:
        print("the given {} is odd".format(num))

for i in range(5):
    num=random.randint(10,30)
    even_odd(num)
# Out:
# the given 20 is even
# the given 13 is odd
# the given 14 is even
# the given 23 is odd
# the given 16 is even

# %%
# 5 lines of code
# take a random no. from random package between 1 to 10
# ================ you need to repeat 3 times ==========
# ask the user enter a no. b/w 1 to 10
# if the no.==random no.,then print("you won"),else print("you lost").

# %%
import random
for i in range(3):
    num1=random.randint(1,10)
    num2=eval(input("Enter a num b/w 1 and 10:"))
    if num1==num2:
              print("you won")
    else:
        print("you lost")
# Out:
# Enter a num b/w 1 and 10: 2
# you lost
# Enter a num b/w 1 and 10: 3
# you lost
# Enter a num b/w 1 and 10: 4
# you lost

# %%
def compare(num1,num2):
    
    
    if num1==num2:
        print("You won")
    else:
        print("You lost")

import random
for i in range(3):


    compare( num1= eval(input("Enter a no. between 1 to 10: ")),num2=random.randint(1,10))
# Out:
# Enter a no. between 1 to 10:  10
# You lost
# Enter a no. between 1 to 10:  9
# You lost
# Enter a no. between 1 to 10:  4
# You lost

# %%
import random
random_num=random.randint(1,10)
print(random_num)
for i in range(3):
    user_num=eval(input("enter number between 1 and 10:"))
    if user_num==random_num:
        print("you won")
    break

else:
    print("you lost")
# Out:
# 9
# enter number between 1 and 10: 9
# you won

# %%
#### Improvise above code
# you need to mention number of chances left
# the user whenever he fails/lose

import random
random_num=random.randint(1,10)
print(random_num)
chances=eval(input("enter how many chances you want:"))
for i in range(chances):
    user_num=eval(input("enter number between 1 and 10:"))
    if user_num==random_num:
        print("you won")
        break
    
    else:
        print("you lost")
        print("the number of chances left is: ",chances-1-i)
# Out:
# 10
# enter how many chances you want: 3
# enter number between 1 and 10: 4
# you lost
# the number of chances left is:  2
# enter number between 1 and 10: 5
# you lost
# the number of chances left is:  1
# enter number between 1 and 10: 6
# you lost
# the number of chances left is:  0

# %%
# Improvise above code 
# whenever the user lost all the chances
# it should print all the chances are over
# print('pls try again after 10 mins)

import random
random_num=random.randint(1,10)
print(random_num)
chances=eval(input("enter how many chances you want: "))
for i in range(chances):
    user_num=eval(input("enter number between 1 and 10: "))
    if user_num==random_num:
        print("you won")
        break

    elif chances-1-i==0:
        print("You lost")
        print("all chances are over")
        print("please try again after 10 mins")
    else:
        print("you lost")
        print("the number of chances left is: ",chances-1-i)

# chances=3
# i=0   2    10    if 2==10 F ======> elif 3-1-0:2==0 F ====> else: 2
# i=1   2    10    if 2==10 F ======> elif 3-1-1:1==0 F ====> else: 1
# i=2   2    10    if 2==10 F ======> elif 3-1-2:0==0 T
# Out:
# 7
# enter how many chances you want:  3
# enter number between 1 and 10:  2
# you lost
# the number of chances left is:  2
# enter number between 1 and 10:  3
# you lost
# the number of chances left is:  1
# enter number between 1 and 10:  4
# You lost
# all chances are over
# please try again after 10 mins
